# %%
import pandas as pd

df_events = pd.read_csv('events.csv')
df_events = df.dropna(axis=1,how='all')
df_events.columns = df_events.columns.str.lower()
df_events.shape



df_clt = pd.read_excel('cltdata.xlsx')
df_clt.columns = df_clt.columns.str.lower()
df_clt.head()
# Out:
#        name                  id    quarter  complete__c         createddate  \
# 0  SR-74047  a1FG0000005Z4D3MAK  2017 - Q1            1 2017-01-06 18:27:54
# 1  SR-74048  a1FG0000005Z4D4MAK  2017 - Q1            1 2017-01-06 18:27:54
# 2  SR-74049  a1FG0000005Z4D5MAK  2017 - Q1            1 2017-01-06 18:27:54
# 3  SR-74050  a1FG0000005Z4D6MAK  2017 - Q1            0 2017-01-06 18:27:54
# 4  SR-74051  a1FG0000005Z4D7MAK  2017 - Q1            0 2017-01-06 18:27:54
#
#          start_date__c  start_quarter__c  start_year__c calling_quarter__c  \
# 0  2017-01-09 00:00:00               1.0         2017.0              Q1/Q3
# 1  2017-01-09 00:00:00               1.0         2017.0              Q1/Q3
# 2  2017-01-09 00:00:00               1.0         2017.0              Q1/Q3
# 3  2017-01-09 00:00:00               1.0         2017.0              Q1/Q3
# 4  2017-01-09 00:00:00               1.0         2017.0              Q1/Q3
#
#                                        question_2__c  \
# ...

# %%
#df_clt_time = df_clt.loc[:,['id',pd.to_datetime('createddate',format='%Y-%m-%d %H:%M:%S').timestamp.dt.hour]]
#df_clt_time.head()
df_clt['createddate'].dtype
# Out:
# dtype('<M8[ns]')
